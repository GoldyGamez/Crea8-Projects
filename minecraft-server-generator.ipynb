# %% [markdown]
# #Generate A Minecraft Server For Free!
# **Don't Forget To Save A Copy In Your Google Drive Or The Server Will Get Deleted In 12 Hours**
#
# **Patreon:- https://patreon.com/crea8patreon/**
#
# **Link Is In Description

# %%
#@title 1. Install OpenJDK 16
# !wget -qO - https://adoptopenjdk.jfrog.io/adoptopenjdk/api/gpg/key/public | sudo apt-key add -
# !sudo add-apt-repository --yes https://adoptopenjdk.jfrog.io/adoptopenjdk/deb/

# %%
#@title 2. Server Setup
print("Do You Accept The Crea8 Licence? (y/n)")
licenseinp = input(": ")
if licenseinp == "n" :
  print("You Have Cancelled The Crea8 License.")
if licenseinp == "y" :
  print("Select Your Minecraft Platform")
  print("(1)Minecraft Java (2)Minecraft Bedrock")
  mcplatform = int(input(": ")) 
  if mcplatform == 1 :
    print("Select Your Server Software")
    print("(1)Spigot (2)CraftBukkit")
    javaser = int(input(": "))
    if javaser == 1 :
      print("If You Liked This Project, Please Consider Donating At https://patreon.com/crea8patreon/")
    
    # !wget -O spigot.jar https://download.getbukkit.org/spigot/spigot-1.17.1.jar
    # !rm craftbukkit.jar
    if javaser == 2 :
      print("If You Liked This Project, Please Consider Donating At https://patreon.com/crea8patreon/")
    
    # !wget -O craftbukkit.jar https://download.getbukkit.org/craftbukkit/craftbukkit-1.17.1.jar
  
  if mcplatform == 2:
    print("Select Your Server Software")
    print("(1)PowerNukkit (2)PocketMine-MP")
    bedrockser = int(input(": "))
    if bedrockser == 1 :
      
      print("If You Liked This Project, Please Consider Donating At https://patreon.com/crea8patreon/")
    
      # !wget -O powernukkit.jar https://repo1.maven.org/maven2/org/powernukkit/powernukkit/1.5.1.0-PN/powernukkit-1.5.1.0-PN-shaded.jar
    
    if bedrockser == 2:
      print("If You Liked This Project, Please Consider Donating At https://patreon.com/crea8patreon/")
      
      # !rm powernukkit.jar
      # !wget -q -O - https://raw.githubusercontent.com/pmmp/php-build-scripts/master/installer.sh | bash -s - -r

# %%
#@title Console
# !java -Xms10G -Xmx10G -jar spigot.jar
# !java -Xms10G -Xmx10G -jar craftbukkit.jar
# !java -Xms10G -Xmx10G -jar powernukkit.jar
# !./start.sh
