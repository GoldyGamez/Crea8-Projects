# %% [markdown]
# #**Calculate Maths For Free!**
# **Don't Forget To Save A Copy In Your Google Drive If You Want To Use It For Later Purposes**
#
# **Patreon:- https://patreon.com/crea8patreon/**
#
#
# **Link Is In Description

# %%
#@title Crea8 Calculator
print("---------------------------------------------------------")
print("Crea8 Calculator")
print("")
print("Select Your Math Type")
print("(1)Multiplication (2)Division (3)Addition (4)Subtraction")
mathtypeinp = int(input(": "))
if mathtypeinp == 1 :
  num1 = int(input("Enter Your 1st Number:- "))
  num2 = int(input("Enter Your 2nd Number:- "))
  ans = num1*num2
  print("")
  print("If You Liked This Project, Please Consider Donating At https://patreon.com/crea8patreon/")
  print("")
  print("Your Multiplication Answer Is", ans)
  print("")
  print("Powered By Crea8 License")
  print("---------------------------------------------------------")
if mathtypeinp == 2 :
  num1 = int(input("Enter Your 1st Number:- "))
  num2 = int(input("Enter Your 2nd Number:- "))
  ans = num1/num2
  print("")
  print("If You Liked This Project, Please Consider Donating At https://patreon.com/crea8patreon/")
  print("")
  print("Your Division Answer Is", ans)
  print("")
  print("Powered By Crea8 License")
  print("---------------------------------------------------------")
if mathtypeinp == 3 :
  num1 = int(input("Enter Your 1st Number:- "))
  num2 = int(input("Enter Your 2nd Number:- "))
  ans = num1+num2
  print("")
  print("If You Liked This Project, Please Consider Donating At https://patreon.com/crea8patreon/")
  print("")
  print("Your Addition Answer Is", ans)
  print("")
  print("Powered By Crea8 License")
  print("---------------------------------------------------------")
if mathtypeinp == 4 :
  num1 = int(input("Enter Your 1st Number:- "))
  num2 = int(input("Enter Your 2nd Number:- "))
  ans = num1-num2
  print("")
  print("If You Liked This Project, Please Consider Donating At https://patreon.com/crea8patreon/")
  print("")
  print("Your Subtraction Answer Is", ans)
  print("")
  print("Powered By Crea8 License")
  print("---------------------------------------------------------")
