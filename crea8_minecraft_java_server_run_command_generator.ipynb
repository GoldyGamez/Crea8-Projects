# %% [markdown]
# <a href="https://colab.research.google.com/github/GoldyGamez/Crea8-Projects/blob/master/crea8_minecraft_java_server_run_command_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Generate A Minecraft Java Server Run Command For Free!**
# **Don't Forget To Save A Copy In Your Google Drive If You Want To Use It For Later Purposes**
#
# **Patreon:- https://patreon.com/crea8patreon/**
#
#
# **Link Is In Description**

# %%
#@title Crea8 Minecraft Java Server Run Command Generator 
print("Do You Accept The Crea8 License? (y/n)")
license = input(": ")
if license == "y" :
  print("Enter Your Server File Name")
  print("Example: server.jar")
  serverfilename = input(": ")
  print("Enter Your Server's Maximum RAM Usage Size")
  print("In Megabytes Example: -Xmx1024M")
  print("In Gigabytes Example: -Xmx1G")
  maxram = input(": ")
  print("Enter Your Server's Minimum RAM Usage Size")
  print("In Megabytes Example: -Xms1024M")
  print("In Gigabytes Example: -Xms1G")
  minram = input(": ")
  print("Does Your Server Use Its GUI? (y/n)")
  guiinp = input(": ")
  if guiinp == "y" :
    print("Here's Your Minecraft Java Server Run Command")
    print("java", minram, maxram, "-jar", serverfilename)
  if guiinp == "n" :
    print("Here's Your Minecraft Java Server Run Command")
    print("java", minram, maxram, "-jar", serverfilename, "nogui")
if license == "n" :
  print("You Have Cancelled The Crea8 License")
# Out:
# Do You Accept The Crea8 License? (y/n)
# : y
# Enter Your Server File Name
# Example: server.jar
# : async.jar
# Enter Your Server's Maximum RAM Usage Size
# In Megabytes Example: -Xmx1024M
# In Gigabytes Example: -Xmx1G
# : -Xmx1G
# Enter Your Server's Minimum RAM Usage Size
# In Megabytes Example: -Xms1024M
# In Gigabytes Example: -Xms1G
# : -Xmx1024M
# Does Your Server Use Its GUI? (y/n)
# : y
# Here's Your Minecraft Java Server Run Command
# java -Xmx1024M -Xmx1G -jar async.jar
