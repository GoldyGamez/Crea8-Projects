# %% [markdown]
# <a href="https://colab.research.google.com/github/GoldyGamez/Crea8-Projects/blob/master/temporary_powernukkit_server_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Generate A Temporary PowerNukkit Server For Free!**
# **Don't Forget To Save A Copy In Your Google Drive If You Want To Use It For Later Purposes**
#
# **Patreon:- https://patreon.com/crea8patreon/**
#
#
# **Link Is In Description**

# %%
#@title 1. Server Setup
print("Do You Accept The Crea8 License? (y/n)")
license = input(": ")
if license == "y" :
  print("If You Liked This Project, Please Consider Donating At https://patreon.com/crea8patreon/")
  print("")
  # !wget -O powernukkit.jar https://github.com/PowerNukkit/PowerNukkit/releases/download/v1.5.1.0-PN/powernukkit-1.5.1.0-PN-shaded.jar
if license == "n" :
  print("You Have Cancelled The Crea8 License")

# %%
#@title Console
# !java -Xms10G -Xmx10G -XX:+UseG1GC -XX:+ParallelRefProcEnabled -XX:MaxGCPauseMillis=200 -XX:+UnlockExperimentalVMOptions -XX:+DisableExplicitGC -XX:+AlwaysPreTouch -XX:G1NewSizePercent=30 -XX:G1MaxNewSizePercent=40 -XX:G1HeapRegionSize=8M -XX:G1ReservePercent=20 -XX:G1HeapWastePercent=5 -XX:G1MixedGCCountTarget=4 -XX:InitiatingHeapOccupancyPercent=15 -XX:G1MixedGCLiveThresholdPercent=90 -XX:G1RSetUpdatingPauseTimePercent=5 -XX:SurvivorRatio=32 -XX:+PerfDisableSharedMem -XX:MaxTenuringThreshold=1 -Dusing.aikars.flags=https://mcflags.emc.gs -Daikars.new.flags=true -jar powernukkit.jar
